# %% [markdown]
# <a href="https://colab.research.google.com/github/swecomic/xray/blob/master/ipynb/object_info.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone -b dev --single-branch https://github.com/swecomic/xray
# Out:
# Cloning into 'xray'...
# remote: Enumerating objects: 180, done.
# remote: Counting objects: 100% (180/180), done.
# remote: Compressing objects: 100% (145/145), done.
# remote: Total 180 (delta 84), reused 74 (delta 32), pack-reused 0
# Receiving objects: 100% (180/180), 937.88 KiB | 1.24 MiB/s, done.
# Resolving deltas: 100% (84/84), done.

# %%
from xray.Utils import xrayDataLoader as x_loader
from xray.Utils.logger import log

def check_dir(path):
    if path == 'colab':
        train_data_dir = '/content/drive/' + 'Shared drives' + '/YS_NW/2.Data/Train/Data'
        train_coco = '/content/drive/Shared drives/YS_NW/2.Data/Train/Meta/CoCo/coco_rapiscan.json'
    elif path == 'google_drive':
        train_data_dir = 'G:/공유 드라이브/YS_NW/2.Data/Train/Data'
        train_coco = 'G:/공유 드라이브/YS_NW/2.Data/Train/Meta/CoCo/coco_rapiscan.json'
    else:
        train_data_dir = '/data/jiylee/dataset/xray/Train/Data'
        train_coco = '/data/jiylee/dataset/xray/Train/Meta/CoCo/coco_rapiscan.json'

    return train_data_dir, train_coco

def show_class_info():
    train_data_dir, train_data_coco = check_dir(LOCATION_PATH)

    dataset = x_loader.XrayDataSet(root=train_data_dir, annotation=train_data_coco)
    class_list =dataset.get_object_info()

    return class_list

if __name__ == '__main__':
    # location
    LOCATION_PATH = 'colab'
    class_info = show_class_info()

class_info
# Out:
#     cat_id                         cat_nm  train_cnt
# 0        1                        Aerosol       4609
# 1        2                        Alcohol        835
# 2        3                            Awl       4662
# 3        4                            Axe       6785
# 4        5                            Bat       1701
# 5        6                        Battery       2660
# 6        7                         Bullet       4005
# 7        8                    Firecracker       6675
# 8        9                            Gun       8750
# 9       10                       GunParts       6866
# 10      11                         Hammer       8299
# 11      12                      HandCuffs       1671
# 12      13                            HDD       9221
# 13      15                          Knife      18658
# 14      16                         Laptop       3684
# 15      17                        Lighter      22505
# 16      18                         Liquid       4946
# 17      19                          Match       1688
# 18      20                      MetalPipe       4331
# 19      21                   NailClippers       3596
# 20      22                     PrtableGas       3735
# 21      23                            Saw      10495
# 22      24                       Scissors      20767
# 23      25                    Screwdriver      11053
# 24      26                     SmartPhone      20310
# 25      27                      SolidFuel       1666
# 26      28                        Spanner      15876
# 27      29                            SSD       2117
# 28      30           SupplymentaryBattery      22945
# 29      31                       TabletPC       3668
# 30      32                        Thinner        835
# 31      33                            USB       6479
# 32      34                       ZippoOil       1216
# 33      36                          Plier       8308
# 34      37                         Chisel       9135
# 35      38          Electronic cigarettes       2133
# 36      39  Electronic cigarettes(Liquid)       3986
# 37      40                       stun gun        105
# 38      41                 Throwing Knife        953
