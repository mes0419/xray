# %% [markdown]
# <a href="https://colab.research.google.com/github/swecomic/xray/blob/dev/ipynb/object_info.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone -b dev --single-branch https://github.com/swecomic/xray
# Out:
# Cloning into 'xray'...
# remote: Enumerating objects: 206, done.
# remote: Counting objects: 100% (206/206), done.
# remote: Compressing objects: 100% (166/166), done.
# remote: Total 206 (delta 101), reused 85 (delta 37), pack-reused 0
# Receiving objects: 100% (206/206), 945.70 KiB | 8.29 MiB/s, done.
# Resolving deltas: 100% (101/101), done.

# %%
from xray.Utils import xrayDataLoader as x_loader
from xray.Utils.logger import log

def check_dir(path):
    if path == 'colab':
        train_data_dir = '/content/drive/' + 'Shared drives' + '/YS_NW/2.Data/Train/Data'
        train_coco = '/content/drive/Shared drives/YS_NW/2.Data/Train/Meta/CoCo/coco_rapiscan.json'
    elif path == 'google_drive':
        train_data_dir = 'G:/공유 드라이브/YS_NW/2.Data/Train/Data'
        train_coco = 'G:/공유 드라이브/YS_NW/2.Data/Train/Meta/CoCo/coco_rapiscan.json'
    else:
        train_data_dir = '/data/jiylee/dataset/xray/Train/Data'
        train_coco = '/data/jiylee/dataset/xray/Train/Meta/CoCo/coco_rapiscan.json'

    return train_data_dir, train_coco

def show_class_info():
    train_data_dir, train_data_coco = check_dir(LOCATION_PATH)

    dataset = x_loader.XrayDataSet(root=train_data_dir, annotation=train_data_coco)
    class_list =dataset.get_object_info()

    return class_list

if __name__ == '__main__':
    # location
    LOCATION_PATH = 'colab'
    class_info = show_class_info()

class_info
# Out:
# loading annotations into memory...
# Done (t=13.96s)
# creating index...
# index created!
# 2020-08-07 06:19:49.764318 : [ XrayDataloader ] isValid check len : 137761
# 2020-08-07 06:27:30.808070 : [ XrayDataloader ] Empty file found
# 2020-08-07 06:27:30.822241 : [ XrayDataloader ] Dataset Created
# 2020-08-07 06:27:30.823638 : [ XrayDataloader ] isValid check len : 4609
# 2020-08-07 06:27:32.836388 : [ XrayDataloader ] isValid check len : 835
# 2020-08-07 06:27:33.080270 : [ XrayDataloader ] isValid check len : 4662
# 2020-08-07 06:27:34.949247 : [ XrayDataloader ] isValid check len : 6785
# 2020-08-07 06:27:37.636151 : [ XrayDataloader ] Empty file found
# 2020-08-07 06:27:37.639785 : [ XrayDataloader ] isValid check len : 1701
# 2020-08-07 06:27:38.176907 : [ XrayDataloader ] isValid check len : 2660
# 2020-08-07 06:27:39.127018 : [ XrayDataloader ] Empty file found
# 2020-08-07 06:27:39.129844 : [ XrayDataloader ] isValid check len : 4005
# 2020-08-07 06:27:40.566274 : [ XrayDataloader ] isValid check len : 6675
# 2020-08-07 06:27:43.690031 : [ XrayDataloader ] isValid check len : 8750
# 2020-08-07 06:27:47.702139 : [ XrayDataloader ] Empty file found
# 2020-08-07 06:27:47.706829 : [ XrayDataloader ] isValid check len : 6866
# 2020-08-07 06:27:50.833932 : [ XrayDataloader ] isValid check len : 8299
# 2020-08-07 06:27:54.563760 : [ XrayDataloader ] Empty file found
# 2020-08-07 06:27:54.568553 : [ XrayDataloader ] isValid check len : 1671
# 2020-08-07 06:27:55.188429 : [ XrayDataloader ] Empty file found
# 2020-08-07 06:27:55.192561 : [ XrayDataloader ] isValid check len : 9221
# 2020-08-07 06:27:59.221647 : [ XrayDataloader ] Empty file found
# 2020-08-07 06:27:59.234207 : [ XrayDataloader ] isValid check len : 18658
# 2020-08-07 06:28:07.879214 : [ XrayDataloader ] Empty file found
# 2020-08-07 06:28:07.887697 : [ XrayDataloader ] isValid check len : 3684
# 2020-08-07 06:28:09.210741 : [ XrayDataloader ] Empty file found
# 2020-08-07 06:28:09.219781 : [ XrayDataloader ] isValid check len : 22505
# 2020-08-07 06:28:19.575087 : [ XrayDataloader ] Empty file found
# 2020-08-07 06:28:19.584219 : [ XrayDataloader ] isValid check len : 4946
# 2020-08-07 06:28:21.552874 : [ XrayDataloader ] isValid check len : 1688
# 2020-08-07 06:28:22.083315 : [ XrayDataloader ] isValid check len : 4331
# 2020-08-07 06:28:23.583530 : [ XrayDataloader ] Empty file found
# 2020-08-07 06:28:23.586025 : [ XrayDataloader ] isValid check len : 3596
# 2020-08-07 06:28:24.888978 : [ XrayDataloader ] Empty file found
# 2020-08-07 06:28:24.891449 : [ XrayDataloader ] isValid check len : 3735
# 2020-08-07 06:28:26.211319 : [ XrayDataloader ] Empty file found
# 2020-08-07 06:28:26.215462 : [ XrayDataloader ] isValid check len : 10495
# 2020-08-07 06:28:31.115915 : [ XrayDataloader ] Empty file found
# 2020-08-07 06:28:31.126560 : [ XrayDataloader ] isValid check len : 20767
# 2020-08-07 06:28:41.134353 : [ XrayDataloader ] Empty file found
# 2020-08-07 06:28:41.143875 : [ XrayDataloader ] isValid check len : 11053
# 2020-08-07 06:28:45.795939 : [ XrayDataloader ] Empty file found
# 2020-08-07 06:28:45.805585 : [ XrayDataloader ] isValid check len : 20310
# 2020-08-07 06:28:54.628128 : [ XrayDataloader ] Empty file found
# 2020-08-07 06:28:54.636195 : [ XrayDataloader ] isValid check len : 1666
# 2020-08-07 06:28:55.179417 : [ XrayDataloader ] isValid check len : 15876
# 2020-08-07 06:29:02.831529 : [ XrayDataloader ] Empty file found
# 2020-08-07 06:29:02.836407 : [ XrayDataloader ] isValid check len : 2117
# 2020-08-07 06:29:03.651289 : [ XrayDataloader ] isValid check len : 22945
# 2020-08-07 06:29:13.462921 : [ XrayDataloader ] Empty file found
# 2020-08-07 06:29:13.473844 : [ XrayDataloader ] isValid check len : 3668
# 2020-08-07 06:29:14.930441 : [ XrayDataloader ] Empty file found
# 2020-08-07 06:29:14.932781 : [ XrayDataloader ] isValid check len : 835
# 2020-08-07 06:29:15.162188 : [ XrayDataloader ] isValid check len : 6479
# 2020-08-07 06:29:17.668773 : [ XrayDataloader ] Empty file found
# 2020-08-07 06:29:17.672951 : [ XrayDataloader ] isValid check len : 1216
# 2020-08-07 06:29:18.090948 : [ XrayDataloader ] isValid check len : 8308
# 2020-08-07 06:29:21.534399 : [ XrayDataloader ] Empty file found
# 2020-08-07 06:29:21.539445 : [ XrayDataloader ] isValid check len : 9135
# 2020-08-07 06:29:25.325650 : [ XrayDataloader ] Empty file found
# 2020-08-07 06:29:25.329160 : [ XrayDataloader ] isValid check len : 2133
# 2020-08-07 06:29:26.058771 : [ XrayDataloader ] Empty file found
# 2020-08-07 06:29:26.061339 : [ XrayDataloader ] isValid check len : 3986
# 2020-08-07 06:29:27.707180 : [ XrayDataloader ] isValid check len : 105
# 2020-08-07 06:29:27.746615 : [ XrayDataloader ] Empty file found
# 2020-08-07 06:29:27.747880 : [ XrayDataloader ] isValid check len : 953
#     cat_id                         cat_nm  path_data_cnt  anno_data_cnt
# 0        1                        Aerosol           4609           4609
# 1        2                        Alcohol            835            835
# 2        3                            Awl           4662           4662
# 3        4                            Axe           6735           6785
# 4        5                            Bat           1701           1701
# 5        6                        Battery           2652           2660
# 6        7                         Bullet           4005           4005
# 7        8                    Firecracker           6675           6675
# 8        9                            Gun           8673           8750
# 9       10                       GunParts           6866           6866
# 10      11                         Hammer           8243           8299
# 11      12                      HandCuffs           1654           1671
# 12      13                            HDD           9083           9221
# 13      15                          Knife          18531          18658
# 14      16                         Laptop           3573           3684
# 15      17                        Lighter          22410          22505
# 16      18                         Liquid           4946           4946
# 17      19                          Match           1688           1688
# 18      20                      MetalPipe           3973           4331
# 19      21                   NailClippers           3584           3596
# 20      22                     PrtableGas           3641           3735
# 21      23                            Saw          10439          10495
# 22      24                       Scissors          20667          20767
# 23      25                    Screwdriver          11013          11053
# 24      26                     SmartPhone          20202          20310
# 25      27                      SolidFuel           1666           1666
# 26      28                        Spanner          15774          15876
# 27      29                            SSD           2117           2117
# 28      30           SupplymentaryBattery          22807          22945
# 29      31                       TabletPC           3522           3668
# 30      32                        Thinner            835            835
# 31      33                            USB           6425           6479
# 32      34                       ZippoOil           1216           1216
# 33      36                          Plier           8149           8308
# 34      37                         Chisel           9064           9135
# 35      38          Electronic cigarettes           2094           2133
# 36      39  Electronic cigarettes(Liquid)           3986           3986
# 37      40                       stun gun             99            105
# 38      41                 Throwing Knife            953            953
